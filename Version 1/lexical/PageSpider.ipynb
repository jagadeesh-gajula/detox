# %%
#importing all the libaries
import requests
from bs4 import BeautifulSoup
from pprint import PrettyPrinter
import pandas as pd

# %%
#importing all the datasets required for application
data=requests.get('http://facebook.com')
data=data.text
data=BeautifulSoup(data,'lxml')

#df=pd.read_csv('hist_data.csv',encoding = "cp1252")

# %%
#ths clean function will remove all the noncense from the data
# how ever we need to process NLTK before fed into model
def clean(string):
    specials=['!','@','#','$','%','^','&','*','(',')','_','-','+','`','~',
              '?','|','/','"','=','<','>','{','}','[',']'\
             ';',':','.',',','©','®','1','2','3','4','5','6','7','8','9','0']
    for special in specials:    
        string=string.replace(special," ")
    return string

def getit(url):
        seq=[]
        data=requests.get(str(url))
        if data.status_code != 200:
            print("request failed code: ",data.request)
        data=data.text
        data=BeautifulSoup(data,'lxml')
        p=data.find_all('p')
        p.append(data.find_all('a'))
        p.append(data.find_all('h1'))
        p.append(data.find_all('h2'))
        p.append(data.find_all('h5'))
        p.append(data.find_all('td'))
        p.append(data.find_all('title'))
        p.append(data.find_all('b'))
        p.append(data.find_all('i'))
        p.append(data.find_all('label'))
        string=p
        string=str(string)
        string=string.split(',')
        for i in string:
            begin=i.find('>')
            i=i[begin+1:]
            end=i.find('<')
            i=i[:end]
            if len(i)==1 or len(i)==2:
                break
            seq.append(clean(i.strip()))
        s=" "
        return s.join(seq)
        
        
#for link in range(df.shape[0]):
#    url=hi=df.iloc[[link],[0]].values[0][0]
#    print(url,">>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>")
#    print(getit(url))

# %%
import pandas as pd
for i in pd.read_csv('adult.csv').sites:
    try:
        print(getit(i))
    except:
        print("shit",end='\r')
# Out:
# request failed code:  <PreparedRequest [GET]>
#
# shit
# shit
# Please contact us  ICQ            for your personal invite code if you don't have one
#                             We trade in  Amateu Ana Asia BB BDS Big Tit Blac Blowjo Ga India Lesbia Midge Matur MultiNich   XTraffic com
#
# shit
# La page que vous essayez d'accÃ der n'existe pas  Renouvellez votre requete ultÃ rieurement  Profitez du meilleur rapport qualitÃ  prix HÃ bergez votre site web Copyright               Online SAS   BP             Paris CEDEX      RCS Paris B                Online net Console Documentation Services status Webmail Suivez nous sur Twitter Suivez nous sur Facebook
# Создайте на нем сай или перенаправления на другой домен Стабильность и быстродействие Для сайтов на популярных  Профессиональный сайт Профессиональная почта Перенаправление трафика Новый адрес для отправки
# Diese Seite fuer werbebannerserver de befindet sich noch im Aufbau
# request failed code:  <PreparedRequest [GET]>
#
# request failed code:  <PreparedRequest [GET]>
# The initial connection between Cloudflare's network and the origin web server timed out  As a resul  Please try again in a few minutes
# This page is used to test the proper operation of the HTTP
#  server after it has been installed  If you can read this page it means
# that the HTTP server installed at this site is working properly  The fact that you are seeing this page indicates that the
# website you just visited is either experiencing problems or is
# undergoing routine maintenance  If you would like to let the administrators of this website know
#  that you've seen this page instead of the page you expecte you should
#  send them e mail  In genera  For exampl if you experienced problems while visiting www example co  You may now add content to the directory people visiting your website will see this
# page and not your content  To prevent this page from ever being use  public html You are free to use the images below on Linux powered HTTP servers   Thanks for using CentOS WebPanel    For information on CentOS WebPanel please visit the  CentOS WebPanel is Software and it is used to
# power this website; howeve  For exampl if this website is www example co http   whois domaintools com   CentOS WebPanel com http   whois domaintools com HTTP Test Page If you are a member of the general public  If you are the website administrator  About CentOS WebPanel  Note
# request failed code:  <PreparedRequest [GET]>
# The requested URL   was not found on this server
# request failed code:  <PreparedRequest [GET]>
# The requested URL   was not found on this server
# request failed code:  <PreparedRequest [GET]>
# � amp;t��e�k��K�T�L� P���������X���� �� �gl g � � �]� ��B�
# B��w ��W g  l� LևS���iنvl�Ԝ�F f d� ��VJCIl� �n��U � �Z�f��V���������ܝ���  m  �RqU��CM�������Z�� J�WGc� � ��z���� ���im�� c����L� �����IZP�H  �n�UΘ��x  ݭhW� �t� � q̖G qȩ�  ��  �V�m amp;ó���� ���C �XzoǭKϵ�F S ��J� ����uE�Km 	 � �U �p�� ��  ��  amp;ӹB lt; �h��V;�A�Csѐ�\�r R�� �l��  sV� ���X  amp;kc�� ��l  ���ɖ�� �u �S�
# �� jUc�F u
# request failed code:  <PreparedRequest [GET]>
# The requested URL   was not found on this server
# Vendo is onze geauthoriseerde wederverkoper
# request failed code:  <PreparedRequest [GET]>
#
# request failed code:  <PreparedRequest [GET]>
# No input file specified
# request failed code:  <PreparedRequest [GET]>
# The requested URL   was not found on this server
# request failed code:  <PreparedRequest [GET]>
# The requested URL   was not found on this server
# request failed code:  <PreparedRequest [GET]>
#
# request failed code:  <PreparedRequest [GET]>
#
# request failed code:  <PreparedRequest [GET]>
#
# request failed code:  <PreparedRequest [GET]>
# While trying to retrieve the requested URL the following error was encountered  Some aspect of the requested URL is incorrect   Possible problems  Footprint          FPMCP Footprint          FPMCP ERROR The requested URL could not be retrieved
# request failed code:  <PreparedRequest [GET]>
#
#    New DVDs per day   Watch DVDs online today   Over
# shit
# request failed code:  <PreparedRequest [GET]>
#
# request failed code:  <PreparedRequest [GET]>
#
# request failed code:  <PreparedRequest [GET]>
#
# shit
#   ads  controller php does not existsThe static file does not exist    ads  static phpThe static file does not exist  ads  static php
#
# request failed code:  <PreparedRequest [GET]>
#
#
#
#  Privacy Policy Terms of Use
#
# JuicyAds   The Sexy Advertising Network
#                 Sorr
# shit
#  Looking for sex  Hoping to meet someone special for a ho Sign up swinger group threesome  Adult dating through Adult FriendFinder saves you time and effort  AdultFriendFinder com is engineered to help you quickly find and connect with your best adult dating matches  While you can find friends for adult date and get laid if you and your partners want to get it on  When you browse our sex personal you'll immediately find there are many local adult matches for yo sex dating  Wanna chat online   Looking for erotic sex dating advic and information about sex  At AdultFriendfinder co we have thousands of articles and member blogs devoted to se and sex dating  Educate yourself on an endless number of erotic topic and get real community member input on sex datin fetishe swingin alternative datin  Just because you're on the go doesn't mean you have to miss out on all the fun  With send email message view cam and chat right from your mobile device  Find sex hookups anywher
# request failed code:  <PreparedRequest [GET]>
#
# shit
# For most sites we can offer banner and button placement hard coded text link and gallery spots  If you don't see the type of ad you'd like to plac  Current sites in our portfolio                                                            One week placements are available as wel  To purchase any of the above ad spot or to get your site listed her  Ravo
# shit
# request failed code:  <PreparedRequest [GET]>
#
# shit
# shit
# request failed code:  <PreparedRequest [GET]>
#
#
# shit
#
#  Home Signup Login  H Porn
#
# request failed code:  <PreparedRequest [GET]>
#
# request failed code:  <PreparedRequest [GET]>
# This website is using a security service to protect itself from online attacks  You performed an action that triggered the service and blocked your request  REFERENCE ID Security services provided by StackPath StackPath Sorr
# shit
# request failed code:  <PreparedRequest [GET]>
# File not found
# shit
# Privacy Policy amateurdevils com
# vm
# shit
#
# request failed code:  <PreparedRequest [GET]>
# The requested URL was not found on this server
# request failed code:  <PreparedRequest [GET]>
# The requested URL was not found on this server
# request failed code:  <PreparedRequest [GET]>
# The requested URL was not found on this server
# shit
